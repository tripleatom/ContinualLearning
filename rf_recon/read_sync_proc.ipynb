# %%
import pickle

# %%
proc_file = r"D:\cl\video\Imaging_source_test_2024-11-27_1_PROC"

with open(proc_file, 'rb') as f:
    data = pickle.load(f)

data
# Out:
# {'signal': array([0., 0., 0., ..., 0., 0., 0.]),
#  'signal_time': array([1.73273371e+09, 1.73273371e+09, 1.73273371e+09, ...,
#         1.73273374e+09, 1.73273374e+09, 1.73273374e+09])}

# %%
import matplotlib.pyplot as plt
plt.plot(data['signal_time'], data['signal'])
