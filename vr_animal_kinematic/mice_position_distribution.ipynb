# %%
import pickle

# %%
Animal='CnL14'
date = '2024-09-15'
session = 1

proc_file = rf"\\10.129.151.108\xieluanlabs\xl_cl\batch1_video\Imaging_source_{Animal}_{date}_{session}_PROC"

data = pickle.load(open(proc_file, 'rb'))
data.keys()
# Out:
# dict_keys(['start_time', 'frame_time', 'time_stamp', 'step', 'signal', 'photodiode_read', 'photodiode_time', 'x_pos', 'y_pos', 'heading_direction', 'head_angle'])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.scatter(data['x_pos'], data['y_pos'], c=data['time_stamp'], alpha=0.1, s=5)
plt.title(f"{Animal}_{date}_{session}")
plt.tight_layout()
plt.savefig(rf"\\10.129.151.108\xieluanlabs\xl_cl\code\behavior_analysis\{Animal}_{date}_{session}_position_scatter.png")

# %% [markdown]
# velocity distribution
